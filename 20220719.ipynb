# %% [markdown]
# > 이화여대 강제원 교수님
#
# > LG AIMERS 교육 中 SL Foundation

# %% [markdown]
# ![image.png](attachment:6d7a61d5-8114-4e35-9b8b-3e8126b6f38e.png)

# %% [markdown]
# ![image.png](attachment:6991f3e4-c1bf-4685-b466-a62a994194c2.png)

# %% [markdown]
# model selection
#
# - 풀고자 하는 문제에 가장 적합한 모델을 선택하는 것

# %% [markdown]
# errors
#
# - squared error
# - binary error
#
# - ![image.png](attachment:d84d68c7-0ec5-4b1f-918b-5e57736f483a.png)

# %% [markdown]
# - ![image.png](attachment:261870b6-b0fc-431d-89d2-c9086a790559.png)

# %% [markdown]
# objective 1 : 우리가 학습한 모델이 일반적 성능을 제공하도록 하는 것
#
# - 일반적 성능 ? 분산이 작은 것!
# - 실패한다면 오버피팅인 것. 즉, 일반적인 test 환경에서 적용 불가
# - 추가데이터를 통해 해결할 수도 있고 일반화하여 해결할 수도 있다
#
# objective 2 : 모델의 정확도가 향상된 것
#
# - 편차가 낮아지는 것
# - 실패한다면 언더피팅인 것
# - 좀 더 복잡한 모델을 사용하거나 최적화를 통해 해결할 수 이슴

# %% [markdown]
# ![image.png](attachment:a2bd1a2a-1c32-4810-a39c-dede43c9ca69.png)

# %% [markdown]
# ![image.png](attachment:4cd13ab3-f110-4d7a-9030-88660217c942.png)

# %% [markdown]
# 모델이 복잡해지면 오버피팅 발생 쉽고, bias는 줄어들지만 variance는 상승

# %% [markdown]
# ---

# %% [markdown]
# 딥러닝과 같은 오늘날의 머신러닝 모델은 이미지나 비디오등과 같은 고차원의 데이터를 다루기 때문에 그 복잡도가 굉장히 증가중 => 하지만 복잡도가 증가하는 속도에 비해서 데이터 셋 샘플수는 쉽게 늘리지 못함 => 오버피팅문제 $\uparrow$ => 차원의 저주!

# %% [markdown]
# - 데이터를 늘리면 되잖아
#   - 쉽지 않음. 상당한 비용이 소요됨
#   - 그렇다면 data augmentation 대안은?
#     - 데이터를 변형하거나, 샘플을 생성 혹 합성하여 그 수를 늘림
#     - 1. Regularization
#     - 2. Ensemble

# %% [markdown]
# - 아래의 CV는 data augmentation의 대안이 될 수 있음(교차 검증)

# %% [markdown]
# ![image.png](attachment:f81957aa-d0a6-4eed-a21b-0e240d3e6e78.png)

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# ### Linear Regression
# - Linear models
# - 이때, x에 대해 선형식이 아닐 수 있음
# - 장점? 굉장히 단순하다, 선형 모델이기 때문에 어떤 입력 변수가 출력에 어느 정도 영향을 주는지 가늠할 수 있음

# %% [markdown]
# 주어진 입력에 대해 출력과의 선형적인 관계를 추론하는 문제

# %% [markdown]
# 어떤 predictor를 사용할 것인가?
#
# - Univariate? or Multi?

# %% [markdown]
# > parameter optimization??

# %% [markdown]
# 모델의 parameter가 달라짐에 따라서 주어진 data에 피팅하는 과정에서 오차가 발생하게 될 것.

# %% [markdown]
# ![image.png](attachment:80e9fe5e-9bdb-445a-b1db-53e615abb454.png)

# %% [markdown]
# ![image.png](attachment:821744c5-dc73-4602-9b0a-f3c759a20e53.png)

# %% [markdown]
# 아래 두 그림에서 cost가 줄어든 것을 알 수 있음

# %% [markdown]
# ![image.png](attachment:1482479c-009b-4b21-a564-756552afbe16.png)

# %% [markdown]
# - 하지만 데이터 숫자가 늘어나면 비효율적일 수 있음
# - 더욱이 matrix의 inverse가 존재하지 않을 수도 있음

# %% [markdown]
# ---

# %% [markdown]
# >  ### Global Optimum? Local Optimum?

# %% [markdown]
# Gradient descent algorithm => 반복적으로 해를 구해가는 과정
#
# Normal equation => 원스텝으로 해를 구해가는 과정

# %% [markdown]
# ---
